# %%
import pandas as pd
import numpy as np
from scipy.stats import zscore
from sklearn.decomposition import PCA

# %%
import seaborn as sns

# %%
df = pd.read_excel('PCA India Data_Census.xlsx')
df.head()
# Out:
#    State Code  Dist.Code            State    Area Name  No_HH  TOT_M  TOT_F  \
# 0           1          1  Jammu & Kashmir      Kupwara   7707  23388  29796
# 1           1          2  Jammu & Kashmir       Badgam   6218  19585  23102
# 2           1          3  Jammu & Kashmir  Leh(Ladakh)   4452   6546  10964
# 3           1          4  Jammu & Kashmir       Kargil   1320   2784   4206
# 4           1          5  Jammu & Kashmir        Punch  11654  20591  29981
#
#    M_06  F_06  M_SC  ...  MARG_CL_0_3_M  MARG_CL_0_3_F  MARG_AL_0_3_M  \
# 0  5862  6196     3  ...           1150            749            180
# 1  4482  3733     7  ...            525            715            123
# 2  1082  1018     3  ...            114            188             44
# 3   563   677     0  ...            194            247             61
# 4  5157  4587    20  ...            874           1928            465
#
#    MARG_AL_0_3_F  MARG_HH_0_3_M  MARG_HH_0_3_F  MARG_OT_0_3_M  MARG_OT_0_3_F  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 61 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State Code      640 non-null    int64
#  1   Dist.Code       640 non-null    int64
#  2   State           640 non-null    object
#  3   Area Name       640 non-null    object
#  4   No_HH           640 non-null    int64
#  5   TOT_M           640 non-null    int64
#  6   TOT_F           640 non-null    int64
#  7   M_06            640 non-null    int64
#  8   F_06            640 non-null    int64
#  9   M_SC            640 non-null    int64
#  10  F_SC            640 non-null    int64
#  11  M_ST            640 non-null    int64
#  12  F_ST            640 non-null    int64
#  13  M_LIT           640 non-null    int64
#  14  F_LIT           640 non-null    int64
#  15  M_ILL           640 non-null    int64
#  16  F_ILL           640 non-null    int64
# ...

# %%
df = df.loc[:,['State','Area Name','TOT_M','TOT_F','TOT_WORK_M','TOT_WORK_F','MAINWORK_M','MAINWORK_F']]

# %%
df.head()
# Out:
#              State    Area Name  TOT_M  TOT_F  TOT_WORK_M  TOT_WORK_F  \
# 0  Jammu & Kashmir      Kupwara  23388  29796        6723        3752
# 1  Jammu & Kashmir       Badgam  19585  23102        6982        4200
# 2  Jammu & Kashmir  Leh(Ladakh)   6546  10964        2775        4800
# 3  Jammu & Kashmir       Kargil   2784   4206        1002        1118
# 4  Jammu & Kashmir        Punch  20591  29981        5717        7692
#
#    MAINWORK_M  MAINWORK_F
# 0        2763        1275
# 1        4628        1733
# 2        1940        2923
# 3         491         408
# 4        2523        2267

# %%
sns.relplot(x='TOT_M',y='TOT_F',data = df, hue='State');

# %%
sns.pairplot(df, diag_kind='kde');

# %%
sns.histplot(df['TOT_M']);

# %%
samples = []
for i in range(10000):
    samples.append(np.random.choice(df.TOT_M, 1000).mean())
sns.histplot(samples)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
df.TOT_M.mean(), df.TOT_M.std()
# Out:
# (79940.5765625, 73384.51111369701)

# %%
np.mean(samples)
# Out:
# 79923.02649379999

# %%
np.std(samples)
# Out:
# 2285.648671814189

# %%
df.TOT_M.std()/np.sqrt(1000)
# Out:
# 2320.622000972222

# %%
from scipy.stats import norm

# %%
norm.interval(0.95,loc=np.mean(samples),scale=df.TOT_M.std()/np.sqrt(1000))
# Out:
# (75374.69095016316, 84471.36203743682)

# %%
df['gender_ratio'] = (df.TOT_M/(df.TOT_F))*100

# %%
df.sort_values('gender_ratio')
# Out:
#                State       Area Name   TOT_M   TOT_F  TOT_WORK_M  TOT_WORK_F  \
# 546   Andhra Pradesh         Krishna  137603  314182       69810      146724
# 397           Odisha         Koraput   38026   86272       17870       44720
# 624       Tamil Nadu    Virudhunagar   66704  148445       38587       76432
# 545   Andhra Pradesh   West Godavari  123111  273534       66492      116180
# 390           Odisha           Baudh    8672   19209        4295       10319
# ..               ...             ...     ...     ...         ...         ...
# 138    Uttar Pradesh         Baghpat   54807   64937       24649       12429
# 105        Rajasthan        Dhaulpur   31904   37671       15679       15274
# 143    Uttar Pradesh  Mahamaya Nagar   67258   79378       30629       17018
# 1    Jammu & Kashmir          Badgam   19585   23102        6982        4200
# 586      Lakshadweep     Lakshadweep   12823   14772        5115        1780
#
#      MAINWORK_M  MAINWORK_F  gender_ratio
# ...
